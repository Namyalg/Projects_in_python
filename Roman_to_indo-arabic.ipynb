# %%
#convert a roman number to its indo-arabic equivalent
roman_number = input()
roman_number = roman_number+'0'
arabic = 0
index = 0
roman = {'0' : 0 ,'I':1 , 'V' : 5 , 'X' :10 , 'L':50 , 'C' :100 , 'D' :500 , 'M' : 1000}
while index != len(roman_number)-1:
  if roman[roman_number[index]] >= roman[roman_number[index+1]]:
    arabic += rom[roman_number[index]]
    index += 1
  else:
    arabic += roman[roman_number[index+1]] - roman[roman_number[index]]
    index += 2
print(arabic)
# Out:
# VL
# 45
